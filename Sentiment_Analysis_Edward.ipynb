# %% [markdown]
# <a href="https://colab.research.google.com/github/edward2018211/sentiment-analysis-SOS/blob/master/Sentiment_Analysis_Edward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook is a part of the News Sentiment Analysis project and contains snippets of code. Below is initial setup.

# %%
# Download dependencies
# !pip install ImageScraper # https://pypi.org/project/ImageScraper/

# Import libraries
import tensorflow as tf
import image_scraper as imagescraper
# Out:
# Collecting ImageScraper
#   Downloading https://files.pythonhosted.org/packages/43/4b/e1e2af3b0892cf55fe4db06ce16e6d1d41c6bb95ae208b52109316da948c/ImageScraper-2.0.7-py2.py3-none-any.whl
# Collecting setproctitle>=1.1.8
#   Downloading https://files.pythonhosted.org/packages/5a/0d/dc0d2234aacba6cf1a729964383e3452c52096dc695581248b548786f2b3/setproctitle-1.1.10.tar.gz
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from ImageScraper) (2.23.0)
# Requirement already satisfied: lxml>=3.2.3 in /usr/local/lib/python3.6/dist-packages (from ImageScraper) (4.2.6)
# Requirement already satisfied: future>=0.14.3 in /usr/local/lib/python3.6/dist-packages (from ImageScraper) (0.16.0)
# Collecting SimplePool
#   Downloading https://files.pythonhosted.org/packages/5f/05/1caf229f0baccbbc01978b4c77269e602125815403a7fb1079e63b83be05/SimplePool-0.1.tar.gz
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->ImageScraper) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->ImageScraper) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->ImageScraper) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->ImageScraper) (1.24.3)
# Building wheels for collected packages: setproctitle, SimplePool
#   Building wheel for setproctitle (setup.py) ... done
#   Created wheel for setproctitle: filename=setproctitle-1.1.10-cp36-cp36m-linux_x86_64.whl size=33908 sha256=ded2ca8f7dea86d30e1907038fcb45814c1458e3ff417d598bcd73f807a6150f
#   Stored in directory: /root/.cache/pip/wheels/e6/b1/a6/9719530228e258eba904501fef99d5d85c80d52bd8f14438a3
#   Building wheel for SimplePool (setup.py) ... done
#   Created wheel for SimplePool: filename=SimplePool-0.1-cp36-none-any.whl size=26426 sha256=4710e972320e964ee8f02bb92cbe925de973fcd837e21727e7908807703f2a02
#   Stored in directory: /root/.cache/pip/wheels/ed/66/74/34d30b25b968ba59b2872e551dd962b883441f3772d835ff02
# Successfully built setproctitle SimplePool
# Installing collected packages: setproctitle, SimplePool, ImageScraper
# Successfully installed ImageScraper-2.0.7 SimplePool-0.1 setproctitle-1.1.10

# %% [markdown]
# We will first scrape images from Google using a simple script for processing.

# %% [markdown]
# Next, we will manually label the images that are scraped to use as training data for our model in Tensorflow. An additional suggestion is that we could use data augmentation for more data, but we do need be aware of photos that wouldn't make sense to data augment.

# %% [markdown]
# We will need to do some feature engineering for better prediction accuracy. We'll need multiple layers for our deep neural network and we'll probably want to work in increased stride length for a faster model that uses less memory. Probably dropout too to combat overfitting.

# %% [markdown]
# Once the model is fine-tuned, it will be able to make predictions based on new images (data).

# %% [markdown]
# In addition, we would also like to analyze text associated with the news and not simply pictures. The classical approach is the bag of words approach, instead we'll use word vectors which enhances performance to train our SVM. Below is the setup for our text model.

# %%
# Download large model
# !python -m spacy download en_core_web_lg
# !python -m spacy download en

# Import Libraries
import numpy as np
import spacy
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from google.colab import files
import io

# Need to load the large model to get the vectors
nlp = spacy.load('en')

# Loading the sentiment data
uploaded = files.upload()
sentiment = pd.read_csv(io.BytesIO(uploaded['labeledTrainData.csv']), error_bad_lines=False)
# Out:
# Requirement already satisfied: en_core_web_lg==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz#egg=en_core_web_lg==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.18.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (47.3.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (47.3.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.7.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
#      <input type="file" id="files-70c0544d-a9e6-4933-8141-d3faa39b0d7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70c0544d-a9e6-4933-8141-d3faa39b0d7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labeledTrainData.csv to labeledTrainData (5).csv
# b'Skipping line 4: expected 11 fields, saw 23\nSkipping line 5: expected 11 fields, saw 38\nSkipping line 6: expected 11 fields, saw 20\nSkipping line 14: expected 11 fields, saw 19\nSkipping line 17: expected 11 fields, saw 13\nSkipping line 18: expected 11 fields, saw 13\nSkipping line 19: expected 11 fields, saw 22\nSkipping line 20: expected 11 fields, saw 12\nSkipping line 24: expected 11 fields, saw 12\nSkipping line 30: expected 11 fields, saw 32\nSkipping line 35: expected 11 fields, saw 20\nSkipping line 37: expected 11 fields, saw 12\nSkipping line 39: expected 11 fields, saw 13\nSkipping line 41: expected 11 fields, saw 31\nSkipping line 46: expected 11 fields, saw 12\nSkipping line 50: expected 11 fields, saw 12\nSkipping line 51: expected 11 fields, saw 15\nSkipping line 52: expected 11 fields, saw 13\nSkipping line 61: expected 11 fields, saw 35\nSkipping line 62: expected 11 fields, saw 26\nSkipping line 63: expected 11 fields, saw 12\nSkipping line 68: expected 11 fields, saw 55\nSkipping line 70: expected 11 fields, saw 12\nSkipping line 73: expected 11 fields, saw 13\nSkipping line 78: expected 11 fields, saw 14\nSkipping line 81: expected 11 fields, saw 13\nSkipping line 83: expected 11 fields, saw 17\nSkipping line 84: expected 11 fields, saw 26\nSkipping line 86: expected 11 fields, saw 22\nSkipping line 87: expected 11 fields, saw 14\nSkipping line 88: expected 11 fields, saw 12\nSkipping line 98: expected 11 fields, saw 13\nSkipping line 100: expected 11 fields, saw 12\nSkipping line 103: expected 11 fields, saw 24\nSkipping line 105: expected 11 fields, saw 15\nSkipping line 110: expected 11 fields, saw 19\nSkipping line 111: expected 11 fields, saw 24\nSkipping line 123: expected 11 fields, saw 13\nSkipping line 125: expected 11 fields, saw 13\nSkipping line 127: expected 11 fields, saw 41\nSkipping line 128: expected 11 fields, saw 49\nSkipping line 129: expected 11 fields, saw 22\nSkipping line 133: expected 11 fields, saw 40\nSkipping line 135: expected 11 fields, saw 54\nSkipping line 136: expected 11 fields, saw 19\nSkipping line 138: expected 11 fields, saw 20\nSkipping line 139: expected 11 fields, saw 15\nSkipping line 144: expected 11 fields, saw 18\nSkipping line 147: expected 11 fields, saw 14\nSkipping line 148: expected 11 fields, saw 15\nSkipping line 150: expected 11 fields, saw 26\nSkipping line 153: expected 11 fields, saw 14\nSkipping line 155: expected 11 fields, saw 17\nSkipping line 156: expected 11 fields, saw 21\nSkipping line 158: expected 11 fields, saw 15\nSkipping line 159: expected 11 fields, saw 25\nSkipping line 160: expected 11 fields, saw 20\nSkipping line 162: expected 11 fields, saw 29\nSkipping line 166: expected 11 fields, saw 17\nSkipping line 168: expected 11 fields, saw 26\nSkipping line 174: expected 11 fields, saw 16\nSkipping line 175: expected 11 fields, saw 13\nSkipping line 176: expected 11 fields, saw 25\nSkipping line 178: expected 11 fields, saw 19\nSkipping line 181: expected 11 fields, saw 13\nSkipping line 182: expected 11 fields, saw 23\nSkipping line 183: expected 11 fields, saw 18\nSkipping line 184: expected 11 fields, saw 23\nSkipping line 187: expected 11 fields, saw 12\nSkipping line 189: expected 11 fields, saw 22\nSkipping line 192: expected 11 fields, saw 38\nSkipping line 197: expected 11 fields, saw 16\nSkipping line 205: expected 11 fields, saw 17\nSkipping line 206: expected 11 fields, saw 32\nSkipping line 209: expected 11 fields, saw 12\nSkipping line 213: expected 11 fields, saw 25\nSkipping line 215: expected 11 fields, saw 12\nSkipping line 216: expected 11 fields, saw 85\nSkipping line 218: expected 11 fields, saw 15\nSkipping line 219: expected 11 fields, saw 13\nSkipping line 224: expected 11 fields, saw 31\nSkipping line 227: expected 11 fields, saw 17\nSkipping line 228: expected 11 fields, saw 27\nSkipping line 232: expected 11 fields, saw 24\nSkipping line 233: expected 11 fields, saw 20\nSkipping line 234: expected 11 fields, ...
# ['id\tsentiment\treview']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d7c015d3d4d2> in <module>()
#      20 print(sentiment.columns.tolist())
#      21 with nlp.disable_pipes():
# ---> 22     doc_vectors = np.array([nlp(review).vector for review in sentiment['id\tsentiment\treview']])
#      23
#      24 X_train, X_test, y_train, y_test = train_test_split(doc_vectors, spam.label,
#
# <ipython-input-7-d7c015d3d4d2> in <listcomp>(.0)
#      20 print(sentiment.columns.tolist())
#      21 with nlp.disable_pipes():
# ---> 22     doc_vectors = np.array([nlp(review).vector for review in sentiment['id\tsentiment\treview']])
#      23
#      24 X_train, X_test, y_train, y_test = train_test_split(doc_vectors, spam.label,
#
# /usr/local/lib/python3.6/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     425         DOCS: https://spacy.io/api/language#call
#     426         """
# --> 427         if len(text) > self.max_length:
#     428             raise ValueError(
#     429                 Errors.E088.format(length=len(text), max_length=self.max_length)
#
# TypeError: object of type 'float' has no len()

# %%
with nlp.disable_pipes():
  sentimentText = []
  for row in sentiment.itertuples():
    reviewText = ""
    for line in row:
      if isinstance(line, tuple):
        for section in line:
          if isinstance(section, str):
            reviewText += section
      elif isinstance(line, str):
        reviewText += line
    sentimentText.append(reviewText)
  
  doc_vectors = np.array([nlp(row).vector for row in sentimentText])
  

# X_train, X_test, y_train, y_test = train_test_split(doc_vectors, sentiment.label,
#                                                     test_size=0.1, random_state=1)

# # Set dual=False to speed up training, and it's not needed
# svc = LinearSVC(random_state=1, dual=False, max_iter=10000)
# svc.fit(X_train, y_train)
# print(f"Accuracy: {svc.score(X_test, y_test) * 100:.3f}%", )
# Out:
# 15719
